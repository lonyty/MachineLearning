# 2014-12-31                         0.041186               0.2960
# 2013-12-31                         0.031710               0.1341
#
#             S&P 500, 2 years ago  S&P 500, 3 years ago  S&P 500, 4 years ago  \
# Date
# 2017-12-31               -0.0073                0.1139                0.2960
# 2016-12-31                0.1139                0.2960                0.1341
# 2015-12-31                0.2960                0.1341                0.0000
# 2014-12-31                0.1341                0.0000                0.1278
# 2013-12-31                0.0000                0.1278                0.2345
#
#             S&P 500, 5 years ago  S&P 500, Avg. last 3 years  \
# Date
# 2017-12-31                0.1341                    0.067333
# 2016-12-31                0.0000                    0.134200
# 2015-12-31                0.1278                    0.181333
# 2014-12-31                0.2345                    0.143367
# 2013-12-31               -0.3849                    0.087300
#
#             S&P 500, Avg. last 5 years
# Date
# 2017-12-31                     0.12642
# 2016-12-31                     0.10734
# 2015-12-31                     0.13436
# 2014-12-31                     0.15848
# 2013-12-31                     0.02230
#
# [5 rows x 32 columns]

# %%
col = df_macrodata.columns
col
# Out:
# Index(['Mid Price Fed', 'Tayler Rule Estimate', 'Job Quality Index (JQI)',
#        'Consumer Price Index (yoy %)', 'Unemployment Rate',
#        'Uncertainty About GDP Growth - Broadly Similar',
#        'Risks to GDP Growth - Broadly Balance', 'Optimism Index', 'M2',
#        'OECD Leading Indicator (12-mo % chg)', 'Fed Funds Rate (%)',
#        '3-Month T-Bill Rate (%)', '10-Year Treasury Yield (%)',
#        'Exports of goods, services and income receipts',
#        'Imports of goods, services and income payments',
#        'Personal income (millions of dollars)', 'Population',
#        'Per capita personal income (dollars)',
#        'Total Index Industrial Production', 'Manufacturing',
#        'Oil and gas extraction', 'Mining (except oil and gas)',
#        'Electric power generation', 'Motor vehicles and parts',
#        'Computer and electronic product', 'S&P 500, 1 year ago',
#        'S&P 500, 2 years ago', 'S&P 500, 3 years ago', 'S&P 500, 4 years ago',
#        'S&P 500, 5 years ago', 'S&P 500, Avg. last 3 years',
#        'S&P 500, Avg. last 5 years'],
#       dtype='object')

# %%
#Go trough whole process again

# %%
df2014 = pd.read_csv('raw_data/2014_Financial_Data.csv')
df2015 = pd.read_csv('raw_data/2015_Financial_Data.csv')
df2016 = pd.read_csv('raw_data/2016_Financial_Data.csv')
df2017 = pd.read_csv('raw_data/2017_Financial_Data.csv')
df2018 = pd.read_csv('raw_data/2018_Financial_Data.csv')

# %%
df2014 = df2014.rename({'2015 PRICE VAR [%]':'PRICE_VAR'},axis =1)
df2015 = df2015.rename({'2016 PRICE VAR [%]':'PRICE_VAR'},axis =1)
df2016 = df2016.rename({'2017 PRICE VAR [%]':'PRICE_VAR'},axis =1)
df2017 = df2017.rename({'2018 PRICE VAR [%]':'PRICE_VAR'},axis =1)
df2018 = df2018.rename({'2019 PRICE VAR [%]':'PRICE_VAR'},axis =1)

# %%
# Adding the Benchmark for each year
df2014['S&P 500'] = -0.0073
df2015['S&P 500'] = 0.0954
df2016['S&P 500'] = 0.1942
df2017['S&P 500'] = -0.0624
df2018['S&P 500'] = 0.2888

# %%
for colname in col:

    df2018[colname] = df_macrodata[colname][0]
    df2017[colname] = df_macrodata[colname][1]
    df2016[colname] = df_macrodata[colname][2]
    df2015[colname] = df_macrodata[colname][3]
    df2014[colname] = df_macrodata[colname][4]

# %%
df2018
# Out:
#      Unnamed: 0       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0         CMCSA  9.450700e+10          0.1115     0.000000e+00  9.450700e+10
# 1           KMI  1.414400e+10          0.0320     7.288000e+09  6.856000e+09
# 2          INTC  7.084800e+10          0.1289     2.711100e+10  4.373700e+10
# 3            MU  3.039100e+10          0.4955     1.250000e+10  1.789100e+10
# 4            GE  1.216150e+11          0.0285     9.546100e+10  2.615400e+10
# ...         ...           ...             ...              ...           ...
# 4387       YRIV  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# 4388       YTEN  5.560000e+05         -0.4110     0.000000e+00  5.560000e+05
# 4389       ZKIN  5.488438e+07          0.2210     3.659379e+07  1.829059e+07
# 4390        ZOM  0.000000e+00          0.0000     0.000000e+00  0.000000e+00
# 4391       ZYME  5.301900e+07          0.0243     0.000000e+00  5.301900e+07
#
#       R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# 0     0.000000e+00  6.482200e+10        7.549800e+10      1.900900e+10
# 1     0.000000e+00  6.010000e+08        3.062000e+09      3.794000e+09
# 2     1.354300e+10  6.750000e+09        2.042100e+10      2.331600e+10
# 3     2.141000e+09  8.130000e+08        2.897000e+09      1.499400e+10
# 4     0.000000e+00  1.811100e+10        4.071100e+10     -1.455700e+10
# ...            ...           ...                 ...               ...
# 4387  0.000000e+00  3.755251e+06        3.755251e+06     -3.755251e+06
# 4388  4.759000e+06  5.071000e+06        9.830000e+06     -9.274000e+06
# 4389  1.652633e+06  7.020320e+06        8.672953e+06      9.617636e+06
# 4390  1.031715e+07  4.521349e+06        1.664863e+07     -1.664863e+07
# 4391  5.668400e+07  2.945700e+07        8.614600e+07     -3.312700e+07
#
#       Interest Expense  ...  Electric power generation  \
# 0         3.542000e+09  ...                  -0.011879
# 1         1.917000e+09  ...                  -0.011879
# 2        -1.260000e+08  ...                  -0.011879
# 3         3.420000e+08  ...                  -0.011879
# 4         5.059000e+09  ...                  -0.011879
# ...                ...  ...                        ...
# 4387      1.105849e+07  ...                  -0.011879
# 4388      0.000000e+00  ...                  -0.011879
# 4389      1.239170e+06  ...                  -0.011879
# 4390      0.000000e+00  ...                  -0.011879
# 4391      1.660000e+05  ...                  -0.011879
#
#       Motor vehicles and parts  Computer and electronic product  \
# 0                     -0.00023                         0.043941
# 1                     -0.00023                         0.043941
# 2                     -0.00023                         0.043941
# 3                     -0.00023                         0.043941
# 4                     -0.00023                         0.043941
# ...                        ...                              ...
# 4387                  -0.00023                         0.043941
# 4388                  -0.00023                         0.043941
# 4389                  -0.00023                         0.043941
# 4390                  -0.00023                         0.043941
# 4391                  -0.00023                         0.043941
#
#       S&P 500, 1 year ago  S&P 500, 2 years ago  S&P 500, 3 years ago  \
# 0                  0.0954               -0.0073                0.1139
# 1                  0.0954               -0.0073                0.1139
# 2                  0.0954               -0.0073                0.1139
# 3                  0.0954               -0.0073                0.1139
# 4                  0.0954               -0.0073                0.1139
# ...                   ...                   ...                   ...
# 4387               0.0954               -0.0073                0.1139
# 4388               0.0954               -0.0073                0.1139
# 4389               0.0954               -0.0073                0.1139
# 4390               0.0954               -0.0073                0.1139
# 4391               0.0954               -0.0073                0.1139
#
#       S&P 500, 4 years ago  S&P 500, 5 years ago  S&P 500, Avg. last 3 years  \
# 0                    0.296                0.1341                    0.067333
# 1                    0.296                0.1341                    0.067333
# 2                    0.296                0.1341                    0.067333
# 3                    0.296                0.1341                    0.067333
# 4                    0.296                0.1341                    0.067333
# ...                    ...                   ...                         ...
# 4387                 0.296                0.1341                    0.067333
# 4388                 0.296                0.1341                    0.067333
# 4389                 0.296                0.1341                    0.067333
# 4390                 0.296                0.1341                    0.067333
# 4391                 0.296                0.1341                    0.067333
#
#       S&P 500, Avg. last 5 years
# 0                        0.12642
# 1                        0.12642
# 2                        0.12642
# 3                        0.12642
# 4                        0.12642
# ...                          ...
# 4387                     0.12642
# 4388                     0.12642
# 4389                     0.12642
# 4390                     0.12642
# 4391                     0.12642
#
# [4392 rows x 258 columns]

# %%
print(df2014.shape)
print(df2015.shape)
print(df2016.shape)
print(df2017.shape)
print(df2018.shape)
# Out:
# (3808, 258)
# (4120, 258)
# (4797, 258)
# (4960, 258)
# (4392, 258)

# %%
df = pd.concat([df2014,df2015,df2016,df2017,df2018])
df['PRICE_VAR']=df['PRICE_VAR']/100

# %%
#create index
df.index = np.arange(1,22078)

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
#Threshhold
Threshhold = 22077*(0.5)
df = df.dropna(thresh=Threshhold, axis=1)
df = df.dropna(thresh=220*0.5-2)

# %%
#Creating dummy variables
sector = df['Sector'] 
sector_dummies = pd.get_dummies(sector)
df=df.drop('Sector', axis=1)

# %%
#Estimation missing data points
df = df.fillna(value=df.median())

# %%
#Removing outliers
df = df[np.abs(df-df.mean()) <= (2.33*df.std())].dropna()
df.shape
# Out:
# (11637, 254)

# %%
df = df.join(sector_dummies)

# %%
#Adding classification buy/hold/sell

# %%
dif = df['PRICE_VAR'] - df['S&P 500']

signal = []

for number in dif:
    if number<-0.025:
        signal.append('Sell')
    elif number<0.025:
        signal.append('Hold')       
    else:
        signal.append('Buy')

# %%
df['Signal']= signal

# %%
df = df.drop(['S&P 500','Class','PRICE_VAR'], axis=1)

# %%
df.index = np.arange(1,11638)

# %% [markdown]
# ## Decision Trees

# %%
#Assigning values
X = df.drop('Signal', axis=1)
y = df['Signal']

# %%
# Create Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, stratify=y)

# %%
#scale our data to avoid issues (X_scaled = X_std * (max - min) + min)
from sklearn.preprocessing import MinMaxScaler

# %%
#creating an instance
scaler = MinMaxScaler()

#adjusting scaler only based on the training set (without test values to prevent data leakage)
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
#perform the transformation
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# Create classifier object and fit it to data
forest = RandomForestClassifier(criterion='gini', random_state=0, n_jobs=-1, max_depth=10)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, n_jobs=-1, random_state=0)

# %%
y_pred = forest.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          Buy       0.64      0.40      0.49      1411
#         Hold       0.00      0.00      0.00       225
#         Sell       0.61      0.86      0.71      1856
#
#     accuracy                           0.62      3492
#    macro avg       0.42      0.42      0.40      3492
# weighted avg       0.58      0.62      0.58      3492
# C:\Users\Christian Rauhut\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn import metrics
print('Confusion matrix: \n', 
      metrics.confusion_matrix(y_test, y_pred))
# Out:
# Confusion matrix:
#  [[ 565    0  846]
#  [  55    0  170]
#  [ 258    0 1598]]
